# %%
# !wget http://people.csail.mit.edu/yalesong/tvsum/tvsum50_ver_1_1.tgz
# Out:
# --2023-06-27 11:07:52--  http://people.csail.mit.edu/yalesong/tvsum/tvsum50_ver_1_1.tgz
# Resolving people.csail.mit.edu (people.csail.mit.edu)... 128.30.2.133
# Connecting to people.csail.mit.edu (people.csail.mit.edu)|128.30.2.133|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 671779858 (641M) [application/x-gzip]
# Saving to: ‘tvsum50_ver_1_1.tgz’
#
# tvsum50_ver_1_1.tgz 100%[===================>] 640.66M  19.0MB/s    in 34s
#
# 2023-06-27 11:08:26 (18.8 MB/s) - ‘tvsum50_ver_1_1.tgz’ saved [671779858/671779858]

# %%
# !huggingface-cli login --token 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 --add-to-git-credential
# Out:
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# 首先去自己账号里面 new 一个dataset.  这里面我创立玩数据就是这个https://huggingface.co/datasets/zhangbo2008/video_data 链接能打开.
#那么下面就可以往上面当网盘传数据了.
from huggingface_hub import HfApi
api = HfApi()
rep="zhangbo2008/tvsum"
api.create_repo(repo_id =rep,exist_ok=True,repo_type="dataset") #======注意要写好类型
api.upload_folder(
    folder_path="./",
    repo_id=rep,
    repo_type="dataset",   # 下面这里也要配置好类型.
    
)
#============添加model card 方便别人使用!!!!!!!
from huggingface_hub import ModelCard

content = """
这个数据集可以做视频的高光时刻分类.  from:  https://github.com/yalesong/tvsum
"""

card = ModelCard(content)
card.push_to_hub(repo_id=rep,repo_type='dataset')
# Out:
# tvsum50_ver_1_1.tgz:   0%|          | 0.00/672M [00:00<?, ?B/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# 'https://huggingface.co/datasets/zhangbo2008/tvsum/tree/main/'
