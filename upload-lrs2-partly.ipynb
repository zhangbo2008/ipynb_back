# %%
# !unzip -o main2 a.zip
# Out:
# unzip:  cannot find or open main2, main2.zip or main2.ZIP.

# %%
cp main/5535415699068794046/  main2 -r

# %%
ls main2
# Out:
# 00001.mp4  00003.mp4  00006.mp4  00008.mp4  00011.mp4  00014.mp4
# 00001.txt  00003.txt  00006.txt  00008.txt  00011.txt  00014.txt
# 00002.mp4  00004.mp4  00007.mp4  00009.mp4  00013.mp4
# 00002.txt  00004.txt  00007.txt  00009.txt  00013.txt

# %%
# !huggingface-cli login --token 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 --add-to-git-credential
# Out:
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from huggingface_hub import HfApi
api = HfApi()
rep="zhangbo2008/LRS2_partly"
api.create_repo(repo_id =rep,exist_ok=True,repo_type="dataset") #======注意要写好类型
api.upload_folder(
    folder_path="./main2",
    repo_id=rep,
    repo_type="dataset",   # 下面这里也要配置好类型.
    
)
# Out:
# 'https://huggingface.co/datasets/zhangbo2008/LRS2_partly/tree/main/'
