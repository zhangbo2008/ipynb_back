# %%
# kaggle里面的conda配置不对,需要我们手动修改他的conda信息.

a=r'''
show_channel_urls: true

'''
with open ('/root/.condarc' ,'w') as f:
    f.write(a)

# %%
# !conda create -n langchain python=3.8 -y
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/langchain
#
#   added / updated specs:
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     libgcc-ng-13.1.0           |       he5830b7_0         758 KB  conda-forge
#     libgomp-13.1.0             |       he5830b7_0         409 KB  conda-forge
# ...
